# %%
import h5py
import numpy as np
import random

# Open the HDF5 file in read mode
with h5py.File('train_file.h5', 'r') as f:

    # Load the dataset into a NumPy array
    train_array = np.array(f['my_dataset'])

# Print the shape of the array to verify it was loaded correctly
print(train_array.shape[0])
# Out:
# 80

# %%
(train_array).shape
# Out:
# (80, 176, 12)

# %%
start_stroke,end_stroke = 0,20  # Enter the start and stop for stroke videos for example -> if you have 2 videos it starts at 0 and ends at 1 
start_NoStroke,end_NoStroke = 50,60  # Enter the start and stop for no stroke videos for example -> if you have 2 videos it starts at 2 and ends at 3
#  if we have 4 videos , say, then first 2 are stroke , then index 0 and 1 are for stroke, and 2 and 3 indices are for no stroke

# %% [markdown]
# # TimeDomain Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
for i in range(5):
    print("*************************************************************Sample ", i+1,end = "")
    print("***************************************************")
    p = random.randint(0,20) #video for stroke
    q = random.randint(50,60)#video for NoStroke
    print(p,q)

    ############################
    # FFT of Left Elbow - x
    n = 1
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q]
    signal1_1 = np.array(fft_signal_stroke)
    signal1_2 = np.array(fft_signal_Nostroke)
    ############################
    ############################
    # FFT of Left Elbow - x
    n = 2
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q] 
    signal2_1 = np.array(fft_signal_stroke)
    signal2_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 4
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q] 
    signal4_1 = np.array(fft_signal_stroke)
    signal4_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 5
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q] 
    signal5_1 = np.array(fft_signal_stroke)
    signal5_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 7
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q] 
    signal7_1 = np.array(fft_signal_stroke)
    signal7_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 8
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q] 
    signal8_1 = np.array(fft_signal_stroke)
    signal8_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 10
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q] 
    signal10_1 = np.array(fft_signal_stroke)
    signal10_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 11
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = signal_2d[p] 
    fft_signal_Nostroke =signal_2d[q] 
    signal11_1 = np.array(fft_signal_stroke)
    signal11_2 = np.array(fft_signal_Nostroke)
    ############################



    fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(13, 13))

    # Plot the first graph on the top left subplot
    axes[0, 0].plot(np.abs(signal1_1), label='Stroke signal')
    axes[0, 0].plot(np.abs(signal1_2), label='No Stroke signal')
    axes[0, 0].set_title('Left Elbow - x')
#     axes[0, 0].set_ylim(0, 0.2)
    axes[0, 0].legend()
    axes[0, 0].set_xlabel('X-axis')
    axes[0, 0].set_ylabel('Y-axis')

    # Plot the second graph on the top right subplot
    axes[1, 0].plot(np.abs(signal2_1), label='Stroke signal')
    axes[1, 0].plot(np.abs(signal2_2), label='No Stroke signal')
    axes[1, 0].set_title('Left Wrist - x')
    axes[1, 0].set_xlabel('X-axis')
    axes[1, 0].set_ylabel('Y-axis')
#     axes[1, 0].set_ylim(0, 0.2)
    axes[1, 0].legend()

    # Plot the third graph on the bottom left subplot
    axes[2, 0].plot(np.abs(signal4_1), label='Stroke signal')
    axes[2, 0].plot(np.abs(signal4_2), label='No Stroke signal')
    axes[2, 0].set_title('Right Elbow - x')
    axes[2, 0].set_xlabel('X-axis')
    axes[2, 0].set_ylabel('Y-axis')
#     axes[2, 0].set_ylim(0, 0.2)
    axes[2, 0].legend()

    # Plot the fourth graph on the bottom right subplot
    axes[3, 0].plot(np.abs(signal5_1), label='Stroke signal')
    axes[3, 0].plot(np.abs(signal5_2), label='No Stroke signal')
    axes[3, 0].set_title('Right Wrist - x')
    axes[3, 0].set_xlabel('X-axis')
    axes[3, 0].set_ylabel('Y-axis')
#     axes[3, 0].set_ylim(0, 0.2)
    axes[3, 0].legend()

    ####

    # Plot the fivth graph on the bottom right subplot
    axes[0, 1].plot(np.abs(signal7_1), label='Stroke signal')
    axes[0, 1].plot(np.abs(signal7_2), label='No Stroke signal')
    axes[0, 1].set_title('Left Elbow - y')
    axes[0, 1].set_xlabel('X-axis')
    axes[0, 1].set_ylabel('Y-axis')
#     axes[0, 1].set_ylim(0, 0.2)
    axes[0, 1].legend()



    # Plot the fivth graph on the bottom right subplot
    axes[1, 1].plot(np.abs(signal8_1), label='Stroke signal')
    axes[1, 1].plot(np.abs(signal8_2), label='No Stroke signal')
    axes[1, 1].set_title('Left Wrist - y')
    axes[1, 1].set_xlabel('X-axis')
    axes[1, 1].set_ylabel('Y-axis')
#     axes[1, 1].set_ylim(0, 0.2)
    axes[1, 1].legend()


    # Plot the fivth graph on the bottom right subplot
    axes[2, 1].plot(np.abs(signal10_1), label='Stroke signal')
    axes[2, 1].plot(np.abs(signal10_2), label='No Stroke signal')
    axes[2, 1].set_title('Right Elbow - y')
    axes[2, 1].set_xlabel('X-axis')
    axes[2, 1].set_ylabel('Y-axis')
#     axes[2, 1].set_ylim(0, 0.2)
    axes[2, 1].legend()


    # Plot the fivth graph on the bottom right subplot
    axes[3, 1].plot(np.abs(signal11_1), label='Stroke signal')
    axes[3, 1].plot(np.abs(signal11_2), label='No Stroke signal')
    axes[3, 1].set_title('Right Wrist - y')
    axes[3, 1].set_xlabel('X-axis')
    axes[3, 1].set_ylabel('Y-axis')
#     axes[3, 1].set_ylim(0, 0.2)
    axes[3, 1].legend()




    # Add a common x-axis label and a common y-axis label
    fig.text(0.5, 0.04, 'X-axis', ha='center', va='center')
    fig.text(0.06, 0.5, 'Y-axis', ha='center', va='center', rotation='vertical')

    plt.tight_layout()
    
#     s = "Sample " + str(i+1)
#     fig.suptitle(s)
    plt.show()
# Out:
# *************************************************************Sample  1***************************************************
# 2 52
# *************************************************************Sample  2***************************************************
# 11 54
# *************************************************************Sample  3***************************************************
# 14 58
# *************************************************************Sample  4***************************************************
# 10 55
# *************************************************************Sample  5***************************************************
# 3 51

# %% [markdown]
# # Frequency Domain Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
for i in range(5):
    print("*************************************************************Sample ", i+1,end = "")
    print("***************************************************")
    p = random.randint(start_stroke,end_stroke) #video for stroke
    q = random.randint(start_NoStroke,end_NoStroke)#video for NoStroke
    print(p,q)

    ############################
    # FFT of Left Elbow - x
    n = 1
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal1_1 = np.array(fft_signal_stroke)
    signal1_2 = np.array(fft_signal_Nostroke)
    ############################
    ############################
    # FFT of Left Elbow - x
    n = 2
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal2_1 = np.array(fft_signal_stroke)
    signal2_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 4
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal4_1 = np.array(fft_signal_stroke)
    signal4_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 5
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal5_1 = np.array(fft_signal_stroke)
    signal5_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 7
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal7_1 = np.array(fft_signal_stroke)
    signal7_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 8
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal8_1 = np.array(fft_signal_stroke)
    signal8_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 10
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal10_1 = np.array(fft_signal_stroke)
    signal10_2 = np.array(fft_signal_Nostroke)
    ########################################################
    # FFT of Left Elbow - x
    n = 11
    signal_3d = train_array
    signal_2d = signal_3d[:, :,n]

    fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
    fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
    signal11_1 = np.array(fft_signal_stroke)
    signal11_2 = np.array(fft_signal_Nostroke)
    ############################



    fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(13, 13))

    # Plot the first graph on the top left subplot
    axes[0, 0].plot(np.abs(signal1_1), label='Stroke signal')
    axes[0, 0].plot(np.abs(signal1_2), label='No Stroke signal')
    axes[0, 0].set_title('Left Elbow - x')
    axes[0, 0].set_ylim(0, 0.2)
    axes[0, 0].legend()
    axes[0, 0].set_xlabel('X-axis')
    axes[0, 0].set_ylabel('Y-axis')

    # Plot the second graph on the top right subplot
    axes[1, 0].plot(np.abs(signal2_1), label='Stroke signal')
    axes[1, 0].plot(np.abs(signal2_2), label='No Stroke signal')
    axes[1, 0].set_title('Left Wrist - x')
    axes[1, 0].set_xlabel('X-axis')
    axes[1, 0].set_ylabel('Y-axis')
    axes[1, 0].set_ylim(0, 0.2)
    axes[1, 0].legend()

    # Plot the third graph on the bottom left subplot
    axes[2, 0].plot(np.abs(signal4_1), label='Stroke signal')
    axes[2, 0].plot(np.abs(signal4_2), label='No Stroke signal')
    axes[2, 0].set_title('Right Elbow - x')
    axes[2, 0].set_xlabel('X-axis')
    axes[2, 0].set_ylabel('Y-axis')
    axes[2, 0].set_ylim(0, 0.2)
    axes[2, 0].legend()

    # Plot the fourth graph on the bottom right subplot
    axes[3, 0].plot(np.abs(signal5_1), label='Stroke signal')
    axes[3, 0].plot(np.abs(signal5_2), label='No Stroke signal')
    axes[3, 0].set_title('Right Wrist - x')
    axes[3, 0].set_xlabel('X-axis')
    axes[3, 0].set_ylabel('Y-axis')
    axes[3, 0].set_ylim(0, 0.2)
    axes[3, 0].legend()

    ####

    # Plot the fivth graph on the bottom right subplot
    axes[0, 1].plot(np.abs(signal7_1), label='Stroke signal')
    axes[0, 1].plot(np.abs(signal7_2), label='No Stroke signal')
    axes[0, 1].set_title('Left Elbow - y')
    axes[0, 1].set_xlabel('X-axis')
    axes[0, 1].set_ylabel('Y-axis')
    axes[0, 1].set_ylim(0, 0.2)
    axes[0, 1].legend()



    # Plot the fivth graph on the bottom right subplot
    axes[1, 1].plot(np.abs(signal8_1), label='Stroke signal')
    axes[1, 1].plot(np.abs(signal8_2), label='No Stroke signal')
    axes[1, 1].set_title('Left Wrist - y')
    axes[1, 1].set_xlabel('X-axis')
    axes[1, 1].set_ylabel('Y-axis')
    axes[1, 1].set_ylim(0, 0.2)
    axes[1, 1].legend()


    # Plot the fivth graph on the bottom right subplot
    axes[2, 1].plot(np.abs(signal10_1), label='Stroke signal')
    axes[2, 1].plot(np.abs(signal10_2), label='No Stroke signal')
    axes[2, 1].set_title('Right Elbow - y')
    axes[2, 1].set_xlabel('X-axis')
    axes[2, 1].set_ylabel('Y-axis')
    axes[2, 1].set_ylim(0, 0.2)
    axes[2, 1].legend()


    # Plot the fivth graph on the bottom right subplot
    axes[3, 1].plot(np.abs(signal11_1), label='Stroke signal')
    axes[3, 1].plot(np.abs(signal11_2), label='No Stroke signal')
    axes[3, 1].set_title('Right Wrist - y')
    axes[3, 1].set_xlabel('X-axis')
    axes[3, 1].set_ylabel('Y-axis')
    axes[3, 1].set_ylim(0, 0.2)
    axes[3, 1].legend()




    # Add a common x-axis label and a common y-axis label
    fig.text(0.5, 0.04, 'X-axis', ha='center', va='center')
    fig.text(0.06, 0.5, 'Y-axis', ha='center', va='center', rotation='vertical')

    plt.tight_layout()
    
#     s = "Sample " + str(i+1)
#     fig.suptitle(s)
    plt.show()
# Out:
# *************************************************************Sample  1***************************************************
# 15 58
# *************************************************************Sample  2***************************************************
# 20 55
# *************************************************************Sample  3***************************************************
# 8 55
# *************************************************************Sample  4***************************************************
# 13 55
# *************************************************************Sample  5***************************************************
# 5 56

# %%
p = random.randint(11,30) #video for stroke
q = random.randint(50,60)#video for NoStroke
n = 8
print(p,q)
signal_3d = train_array
signal_2d = signal_3d[:, :,n]
fft_signal_stroke = np.fft.fft(signal_2d[p], axis=0) 
fft_signal_Nostroke = np.fft.fft(signal_2d[q], axis=0) 
signal8_1 = np.array(fft_signal_stroke)
signal8_2 = np.array(fft_signal_Nostroke)



# Plot the FFT of both signals
plt.plot(np.abs(signal8_1), label='Stroke signal')
plt.plot(np.abs(signal8_2), label='No stroke signal')

# Add labels and title to the graph
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.title('FFT of Right Wrist-y Sample 4')
plt.ylim(0,0.2)
# plt.xlim(70,80)
# Add a legend
plt.legend()
# 17 51
# Show the graph
plt.show()
# Out:
# 16 58
